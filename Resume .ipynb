# %% [markdown]
# # <center>Resume</center>

# %% [markdown]
# ![](![IMG-20230525-WA0010.jpg](attachment:IMG-20230525-WA0010.jpg))

# %% [markdown]
# ![IMG-20230525-WA0010.jpg](attachment:IMG-20230525-WA0010.jpg)

# %% [markdown]
# ### Objective :-

# %% [markdown]
# To work in a premier organization which gives me ample opportunities to apply my skills,
# enhance them, to grow and to contribute in the most effective manner by being a key and an
# effective team player

# %% [markdown]
# ### Education:-

# %% [markdown]
# • B-Tech in (Computer Science Engineering) from Sri Chaitanya Technical Campus affiliated to
# JNTUH University, Hyderabad, with CGPA of 6.4 in the year 2023.
#
# •Diploma in EEE from Brilliant Institute of Eng & Tech affiliated to JNTUH University,
# Hyderabad, with an aggregate of 70% in the year 2016.
#
# • CBSE from Panineeya Mahavidhyalaya Public School, with GPA of 6.4 in the year 2013.

# %% [markdown]
# ### Techincal Skills:-

# %% [markdown]
# • Programming language: C , C++, Python
# • Database Management Systems: SQL.

# %% [markdown]
# ### Personal Profile:-

# %% [markdown]
# - Father Name : A.RAJU
# - Mother Name : A.HYMAVATHI
# - Date of Birth : 03rd June 1998
# - Languages Known : English, Telugu, and Hindi.
# - Hobbies : Social Networking, Playing Cricket.
# - Address : H.No: 11-6-69/2, Road no-1, Pochammabagh colony,Saroornagar, Hyderabad.

# %% [markdown]
# ### Acknowledment:-

# %% [markdown]
# I hereby declare that all the details furnished here are true to the best of my knowledge.

# %% [markdown]
# ### Links:- For my links

# %% [markdown]
# 1. Click[Here](https://www.hackerrank.com/arajulaprasanna1) For Hacker Rank.
# 2. Click[Here](https://medium.com/@arajulaprasannakumar1998) For Medium.
# 3. click[Here](https://www.kaggle.com/prasannakumar1501) For Kaggle.
# 4. Click[Here](https://github.com/Prasanna4438/Prasanna-Kumar.git) For Github.
